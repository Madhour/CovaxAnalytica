# %%
import pandas as pd
import numpy as np

# %%
hydrate_tweets = pd.read_json("../data/raw/Hydrated_Tweets.jsonl", lines=True)

# %%
hydrate_tweets
# Out:
#                       created_at                   id               id_str  \
# 0      2021-04-01 07:37:52+00:00  1377525606708088800  1377525606708088832
# 1      2021-04-01 10:15:04+00:00  1377565168662503400  1377565168662503424
# 2      2021-04-01 07:40:49+00:00  1377526350408388600  1377526350408388608
# 3      2021-04-01 06:54:13+00:00  1377514620718551000  1377514620718551040
# 4      2021-04-01 08:07:34+00:00  1377533079603064800  1377533079603064832
# ...                          ...                  ...                  ...
# 110694 2020-12-01 02:19:25+00:00  1333596536199143400  1333596536199143424
# 110695 2020-12-01 02:46:51+00:00  1333603436462559200  1333603436462559232
# 110696 2020-12-01 02:40:56+00:00  1333601950525509600  1333601950525509632
# 110697 2020-12-01 01:22:18+00:00  1333582161941729300  1333582161941729280
# 110698 2020-12-01 01:48:01+00:00  1333588630737023000  1333588630737022976
#
# ...

# %%
hydrate_tweets.to_csv("../data/raw/Hydrated_Tweets.csv")
