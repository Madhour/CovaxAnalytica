# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Transform Raw Vaccine Tweets

# %%
raw_vaccine_tweets = pd.read_json("../data/raw/vaccine_tweets_hydrated.jsonl", lines=True, encoding="iso-8859-1")

# %% [markdown]
# - annotated dataset is needed later on for model training (tweet sentiment)
# - clean vaccine dataset, keep:
#     - tweet id
#     - date
#     - text
#     - geolocation if possible, else set null
#     - (username for network analysis)
#     - is retweet: boolean (to filter out afterwards)

# %%
raw_vaccine_tweets.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2020-12-13 16:27:13+00:00  1338158543359250400  1338158543359250432
# 1 2020-12-12 19:22:45+00:00  1337840331522453500  1337840331522453504
# 2 2020-12-14 18:00:29+00:00  1338544403795882000  1338544403795881984
# 3 2020-12-12 12:26:34+00:00  1337735595704115200  1337735595704115200
# 4 2020-12-12 20:04:29+00:00  1337850832256176000  1337850832256176128
#
#                                            full_text  truncated  \
# 0  While the world has been on the wrong side of ...      False
# 1  @cnnbrk #COVID19 #CovidVaccine #vaccine #Coron...      False
# 2  The FDA Authorizes Emergency Use Of The Pfizer...      False
# 3  The #FDA finally issues #EUA now comes the pro...      False
# 4  There have not been many bright days in 2020 b...      False
#
#   display_text_range                                           entities  \
# 0           [0, 275]  {'hashtags': [{'text': 'covid19', 'indices': [...
# 1           [8, 173]  {'hashtags': [{'text': 'COVID19', 'indices': [...
# 2           [0, 263]  {'hashtags': [{'text': 'PFE', 'indices': [79, ...
# 3           [0, 224]  {'hashtags': [{'text': 'FDA', 'indices': [4, 8...
# 4           [0, 276]  {'hashtags': [{'text': 'BidenHarris', 'indices...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 1  <a href="https://mobile.twitter.com" rel="nofo...           1.337811e+18
# 2  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 3  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    in_reply_to_status_id_str  ...  retweeted  possibly_sensitive lang  \
# 0                        NaN  ...      False                 0.0   en
# 1               1.337811e+18  ...      False                 NaN   en
# 2                        NaN  ...      False                 0.0   en
# 3                        NaN  ...      False                 NaN   en
# 4                        NaN  ...      False                 NaN   en
#
#                                    extended_entities quoted_status_id  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2  {'media': [{'id': 1338544352956719000, 'id_str...              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#   quoted_status_id_str quoted_status_permalink  quoted_status  \
# 0                  NaN                     NaN            NaN
# 1                  NaN                     NaN            NaN
# 2                  NaN                     NaN            NaN
# 3                  NaN                     NaN            NaN
# 4                  NaN                     NaN            NaN
#
#    withheld_in_countries  withheld_scope
# 0                    NaN             NaN
# 1                    NaN             NaN
# 2                    NaN             NaN
# 3                    NaN             NaN
# 4                    NaN             NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# # Data preparation

# %% [markdown]
# - Remove duplicate tweets
#     - Drop if retweeted == true
#     - Either remove duplicate text
# - Relevant columns = id, created_at, username, full_text, retweet, hashtags

# %% [markdown]
# ## Remove duplicate tweets

# %%
raw_vaccine_tweets[raw_vaccine_tweets.retweeted == True]
# Out:
# Empty DataFrame
# Columns: [created_at, id, id_str, full_text, truncated, display_text_range, entities, source, in_reply_to_status_id, in_reply_to_status_id_str, in_reply_to_user_id, in_reply_to_user_id_str, in_reply_to_screen_name, user, geo, coordinates, place, contributors, is_quote_status, retweet_count, favorite_count, favorited, retweeted, possibly_sensitive, lang, extended_entities, quoted_status_id, quoted_status_id_str, quoted_status_permalink, quoted_status, withheld_in_countries, withheld_scope]
# Index: []
#
# [0 rows x 32 columns]

# %%
raw_vaccine_tweets.id.count()
# Out:
# 101947

# %%
raw_vaccine_tweets = raw_vaccine_tweets.drop_duplicates(subset=["full_text"], keep='first').reset_index(drop=True)

# %%
raw_vaccine_tweets.id.count()
# Out:
# 101023

# %% [markdown]
# - 924 Tweets were dropped

# %% [markdown]
# ## Select relevant columns

# %%
raw_vaccine_tweets.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'source', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo',
#        'coordinates', 'place', 'contributors', 'is_quote_status',
#        'retweet_count', 'favorite_count', 'favorited', 'retweeted',
#        'possibly_sensitive', 'lang', 'extended_entities', 'quoted_status_id',
#        'quoted_status_id_str', 'quoted_status_permalink', 'quoted_status',
#        'withheld_in_countries', 'withheld_scope'],
#       dtype='object')

# %%
raw_vaccine_tweets = raw_vaccine_tweets[["id_str","created_at","user","geo","full_text", "entities"]]

# %% [markdown]
# ## Selecting user id

# %%
raw_vaccine_tweets["user_id"] = int

for i in range(len(raw_vaccine_tweets)):
    raw_vaccine_tweets.user_id[i] = raw_vaccine_tweets.user[i]["id"]
# Out:
# <ipython-input-10-589c50f79ebf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets.user_id[i] = raw_vaccine_tweets.user[i]["id"]

# %%
raw_vaccine_tweets.user
# Out:
# 0         {'id': 76052772, 'id_str': '76052772', 'name':...
# 1         {'id': 1300382181605494800, 'id_str': '1300382...
# 2         {'id': 1164717209253552000, 'id_str': '1164717...
# 3         {'id': 1316036067754205200, 'id_str': '1316036...
# 4         {'id': 1110032180237852700, 'id_str': '1110032...
#                                 ...
# 101018    {'id': 1504133713, 'id_str': '1504133713', 'na...
# 101019    {'id': 3029283761, 'id_str': '3029283761', 'na...
# 101020    {'id': 1072356934148251600, 'id_str': '1072356...
# 101021    {'id': 1204276725372215300, 'id_str': '1204276...
# 101022    {'id': 1050804894133874700, 'id_str': '1050804...
# Name: user, Length: 101023, dtype: object

# %% [markdown]
# ## Hashtags

# %% [markdown]
# renaming entities column to hashtags:

# %%
raw_vaccine_tweets = raw_vaccine_tweets.rename(columns={'entities': 'hashtags', 'id_str':'id'})

# %% [markdown]
# filtering out hashtags only which are stored in entities>hashtags>text:

# %%
for i in range(len(raw_vaccine_tweets)):
    try:
        raw_vaccine_tweets.hashtags[i] = [value["text"] for value in raw_vaccine_tweets.iloc[i]["hashtags"]["hashtags"]]
    except:
        print("failed: ",i)
# Out:
# <ipython-input-13-f542ec085c11>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets.hashtags[i] = [value["text"] for value in raw_vaccine_tweets.iloc[i]["hashtags"]["hashtags"]]

# %%
hashtag_dict = {}
for i in range(len(raw_vaccine_tweets)):
    for hashtag in raw_vaccine_tweets["hashtags"][i]:
        if hashtag not in hashtag_dict:
            hashtag_dict[hashtag] = 1
        else:
            hashtag_dict[hashtag] += 1

# %% [markdown]
# Identifying relevant hashtags for each vaccine manufacturer:

# %%
sorted(hashtag_dict.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('Moderna', 25268),
#  ('Covaxin', 21670),
#  ('COVID19', 17271),
#  ('SputnikV', 16547),
#  ('vaccine', 11479),
#  ('Pfizer', 8513),
#  ('moderna', 6784),
#  ('PfizerBioNTech', 6480),
#  ('COVAXIN', 6325),
#  ('Sinovac', 6244),
#  ('CovidVaccine', 6070),
#  ('Sinopharm', 5578),
#  ('Covishield', 4971),
#  ('AstraZeneca', 4573),
#  ('coronavirus', 3582),
#  ('vaccinated', 3413),
#  ('COVID19Vaccine', 3331),
#  ('covaxin', 2963),
#  ('vaccination', 2822),
#  ('vaccines', 2488),
#  ('OxfordAstraZeneca', 2488),
#  ('Vaccine', 2442),
#  ('lockdown', 2277),
#  ('China', 2102),
#  ('Covid19', 2018),
#  ('India', 2001),
#  ('COVID', 1937),
#  ('Russia', 1900),
#  ('BharatBiotech', 1896),
#  ('BBMP', 1853),
#  ('covid19', 1686),
#  ('GetVaccinated', 1602),
#  ('PfizerVaccine', 1580),
#  ('oxfordastrazeneca', 1527),
#  ('pfizer', 1418),
#  ('PfizerBiontech', 1399),
#  ('COVIDVaccination', 1368),
#  ('COVID19Vaccination', 1360),
#  ('CoronaVaccine', 1355),
#  ('covid', 1340),
#  ('Covid', 1059),
#  ('Covid_19', 1057),
#  ('Coronavirus', 1045),
#  ('CovishieldVaccine', 1003),
#  ('COVID19India', 959),
#  ('WHO', 895),
#  ('Vaccination', 840),
#  ('EU', 791),
#  ('mRNA', 790),
#  ('IndiaFightsCorona', 769),
#  ('COVIDVaccine', 768),
#  ('johnsonandjohnson', 759),
#  ('MentalHealth', 750),
#  ('sinovac', 717),
#  ('JohnsonandJohnson', 684),
#  ('modernavaccine', 683),
#  ('VaccineForAll', 678),
#  ('COVISHIELD', 666),
#  ('Sputnik', 655),
#  ('pandemic', 629),
#  ('VaccinesWork', 622),
#  ('sputnikv', 611),
#  ('BioNTech', 608),
#  ('covidvaccine', 607),
#  ('VaccinationDrive', 591),
#  ('covidvacccine', 590),
#  ('LargestVaccineDrive', 575),
#  ('Corona', 570),
#  ('VaccinesSaveLives', 551),
#  ('Pakistan', 548),
#  ('covishield', 537),
#  ('SriLanka', 519),
#  ('Jesus', 516),
#  ('COVIDã\x83¼19', 508),
#  ('MentalHealthMatters', 508),
#  ('covid_19', 503),
#  ('health', 471),
#  ('COVIDSecondWave', 467),
#  ('CoronavirusVaccine', 464),
#  ('UK', 461),
#  ('healthcare', 459),
#  ('astrazeneca', 457),
#  ('AstraZenaca', 447),
#  ('Vaccines', 446),
#  ('NarendraModi', 430),
#  ('COVAX', 424),
#  ('FDA', 403),
#  ('BREAKING', 399),
#  ('PMModi', 373),
#  ('news', 370),
#  ('Ocugen', 369),
#  ('Delhi', 363),
#  ('US', 360),
#  ('NHS', 351),
#  ('Canada', 339),
#  ('lka', 338),
#  ('OCGN', 336),
#  ('JohnsonAndJohnson', 334),
#  ('FullyVaccinated', 334),
#  ('CoronavirusIndia', 332),
#  ('sinopharm', 326),
#  ('USA', 321),
#  ('mentalhealth', 317),
#  ('CoWIN', 317),
#  ('UAE', 314),
#  ('Chinese', 314),
#  ('CovidVaccines', 311),
#  ('PfizerCovidVaccine', 309),
#  ('SARSCoV2', 308),
#  ('CDC', 306),
#  ('COVIDEmergency', 306),
#  ('cdnpoli', 305),
#  ('Pfizervaccine', 296),
#  ('AIIMS', 293),
#  ('pfizerbiontech', 291),
#  ('ocgn', 288),
#  ('Hyderabad', 286),
#  ('CoronavirusPandemic', 284),
#  ('spring', 281),
#  ('Russian', 280),
#  ('COVID19vaccine', 274),
#  ('Vaccinated', 274),
#  ('india', 271),
#  ('Novavax', 270),
#  ('corona', 264),
#  ('CoronaVac', 261),
#  ('VaccineShortage', 260),
#  ('CovidIndia', 257),
#  ('WearAMask', 252),
#  ('investing', 252),
#  ('seconddose', 251),
#  ('Putin', 249),
#  ('Health', 248),
#  ('FauciOuchie', 245),
#  ('IndiaFightsCOVID19', 245),
#  ('JohnsonAndJohnsonVaccine', 242),
#  ('HongKong', 240),
#  ('science', 239),
#  ('Janssen', 237),
#  ('GurgaonCOVAXIN', 236),
#  ('Covid19Vaccine', 230),
#  ('PfizerBioNtech', 228),
#  ('Modi', 228),
#  ('Johnson', 228),
#  ('BreakingNews', 226),
#  ('COVID19Vaccines', 226),
#  ('Brazil', 225),
#  ('Germany', 218),
#  ('Philippines', 218),
#  ('ocugen', 218),
#  ('Thailand', 217),
#  ('vaccinate', 214),
#  ('COVIDvaccine', 213),
#  ('SputnikUpdates', 213),
#  ('Europe', 212),
#  ('JandJ', 210),
#  ('CoronaVirusUpdates', 209),
#  ('RDIF', 207),
#  ('Israel', 206),
#  ('astrazenecavaccine', 206),
#  ('Biden', 201),
#  ('CoronaSecondWave', 199),
#  ('StaySafe', 198),
#  ('Argentina', 196),
#  ('Mumbai', 196),
#  ('vaccinationdone', 196),
#  ('MumbaiCOVAXIN', 191),
#  ('Iran', 188),
#  ('Remdesivir', 188),
#  ('Syria', 187),
#  ('Slovakia', 186),
#  ('VaccineMaitri', 183),
#  ('CowinApp', 182),
#  ('EMA', 180),
#  ('SinoVac', 179),
#  ('MODERNA', 178),
#  ('COVIDSHIELD', 176),
#  ('COVID19SL', 175),
#  ('Hungary', 173),
#  ('Unite2FightCorona', 172),
#  ('Italy', 170),
#  ('covid19vaccine', 168),
#  ('BigPharma', 168),
#  ('COVID19LK', 165),
#  ('Oxford', 164),
#  ('ICMR', 164),
#  ('CoronaVaccination', 164),
#  ('Fauci', 163),
#  ('Pandemic', 162),
#  ('COVIDIOTS', 161),
#  ('oxfordvaccine', 161),
#  ('Science', 159),
#  ('vaccinations', 159),
#  ('ontariolockdown', 159),
#  ('markets', 159),
#  ('SouthAfrica', 158),
#  ('Pune', 157),
#  ('Maharashtra', 156),
#  ('Covidvax', 156),
#  ('MaskUp', 154),
#  ('Zimbabwe', 154),
#  ('oxygen', 153),
#  ('grateful', 152),
#  ('VaccineRegistration', 152),
#  ('COVIDEmergency2021', 150),
#  ('MadeInIndia', 149),
#  ('MondayMotivation', 148),
#  ('china', 147),
#  ('á´\xa0á´\x80á´\x84á´\x84ÉªÉ´á´\x87ssá´\x80á´\xa0á´\x87Ê\x9fÉªá´\xa0á´\x87s',
#   147),
#  ('CCP', 145),
#  ('VaccineFor18Plus', 145),
#  ('EUA', 143),
#  ('StocksToWatch', 143),
#  ('Biontech', 142),
#  ('Sputnikvaccine', 141),
#  ('COVIDSecondWaveInIndia', 140),
#  ('Bangladesh', 139),
#  ('2nddose', 139),
#  ('LargestVaccinationDrive', 139),
#  ('CoronaVirus', 138),
#  ('mumbai', 137),
#  ('AatmanirbharBharat', 136),
#  ('SINOVAC', 135),
#  ('AtmaNirbharBharat', 133),
#  ('EuropeanUnion', 132),
#  ('COVIDVaccines', 131),
#  ('News', 130),
#  ('Turkey', 129),
#  ('VaccinePassports', 129),
#  ('Covid19UK', 128),
#  ('COVID19vaccines', 127),
#  ('sputnikV', 126),
#  ('ChineseVirus', 126),
#  ('Egypt', 125),
#  ('DeltaVariant', 125),
#  ('coronavirusvaccine', 124),
#  ('ThisIsOurShot', 124),
#  ('COVID19Vic', 124),
#  ('StockMarket', 122),
#  ('Bengaluru', 122),
#  ('getvaccinated', 121),
#  ('StayHome', 121),
#  ('France', 121),
#  ('Mexico', 121),
#  ('Sanofi', 121),
#  ('Dubai', 120),
#  ('Astrazeneca', 120),
#  ('Lockdown', 120),
#  ('lockdown2021', 119),
#  ('bharatbiotech', 119),
#  ('MakeInIndia', 119),
#  ('mondaythoughts', 118),
#  ('Indian', 118),
#  ('Singapore', 116),
#  ('sideeffects', 115),
#  ('Serbia', 115),
#  ('Covid19vaccine', 114),
#  ('Congress', 113),
#  ('OxygenCylinders', 113),
#  ('Covax', 112),
#  ('Ukraine', 112),
#  ('BJP', 112),
#  ('NovelCoronavirus', 112),
#  ('bharatBiotech', 112),
#  ('unite2fightcorona', 112),
#  ('Cambodia', 111),
#  ('medical', 110),
#  ('largestvaccinedrive', 109),
#  ('SerumInstituteofIndia', 108),
#  ('firstdose', 107),
#  ('healthforall', 107),
#  ('CanSino', 107),
#  ('Breaking', 106),
#  ('covaxine', 106),
#  ('OCUGEN', 106),
#  ('DCGI', 106),
#  ('bloodclots', 106),
#  ('COVID19Ontario', 105),
#  ('sensex', 105),
#  ('Malaysia', 104),
#  ('nifty', 104),
#  ('Comirnaty', 103),
#  ('gold', 103),
#  ('COVID_19', 102),
#  ('Africa', 102),
#  ('variants', 102),
#  ('nagpur', 102),
#  ('AI', 101),
#  ('mask', 101),
#  ('California', 100),
#  ('SecondDose', 100),
#  ('Telangana', 100),
#  ('VaccinationCovid', 99),
#  ('silver', 99),
#  ('joebiden', 99),
#  ('tuesdaymotivations', 99),
#  ('BillGates', 98),
#  ('OxfordVaccine', 98),
#  ('TamilNadu', 98),
#  ('Punjab', 98),
#  ('VaccineDiplomacy', 97),
#  ('DollyParton', 97),
#  ('stock', 96),
#  ('phizer', 96),
#  ('SinoPharm', 96),
#  ('maskup', 95),
#  ('vaccineSideEffects', 95),
#  ('Australia', 94),
#  ('virus', 94),
#  ('stocks', 94),
#  ('Nepal', 94),
#  ('Assam', 94),
#  ('JoeBiden', 93),
#  ('ModernaVaccine', 93),
#  ('sputnik', 93),
#  ('Regeneron', 93),
#  ('Trump', 92),
#  ('Covidvaccine', 92),
#  ('covid19vacccine', 92),
#  ('nhs', 92),
#  ('NSTnation', 92),
#  ('SaudiArabia', 92),
#  ('trading', 92),
#  ('bitcoin', 92),
#  ('children', 92),
#  ('VaccinateIndia', 92),
#  ('Indonesia', 91),
#  ('sundayvibes', 91),
#  ('CoronaPandemic', 91),
#  ('onpoli', 90),
#  ('ArvindKejriwal', 90),
#  ('MedTwitter', 89),
#  ('COVID19AB', 89),
#  ('russia', 89),
#  ('VACCINE', 89),
#  ('StocksToBuy', 89),
#  ('Cuba', 88),
#  ('jesus', 88),
#  ('ImranKhan', 87),
#  ('Ontario', 86),
#  ('Bahrain', 86),
#  ('AZ', 86),
#  ('stockmarket', 86),
#  ('BBMPCOVAXIN', 86),
#  ('staysafe', 85),
#  ('Chile', 85),
#  ('PublicHealth', 85),
#  ('PfizerGang', 85),
#  ('PFIZER', 84),
#  ('Moscow', 84),
#  ('wearamask', 84),
#  ('biotech', 83),
#  ('XiJinping', 83),
#  ('coronavaccine', 82),
#  ('jab', 82),
#  ('VAERS', 82),
#  ('Gujarat', 82),
#  ('PuneCOVAXIN', 82),
#  ('auspol', 81),
#  ('premiabiotech', 81),
#  ('cowinregistration', 81),
#  ('hope', 80),
#  ('Karnataka', 80),
#  ('VaccinePassport', 79),
#  ('modernagang', 79),
#  ('Toronto', 78),
#  ('research', 78),
#  ('SPUTNIKV', 78),
#  ('DrReddy', 78),
#  ('CovidVaccination', 77),
#  ('money', 77),
#  ('vaccineshortage', 77),
#  ('medicine', 76),
#  ('OxfordAstrazeneca', 76),
#  ('Chennai', 76),
#  ('2ndDose', 75),
#  ('Covisheild', 75),
#  ('COVID19ON', 75),
#  ('publichealth', 74),
#  ('B117', 74),
#  ('Tech', 74),
#  ('StocksToTrade', 74),
#  ('vaccini', 73),
#  ('Trudeau', 73),
#  ('FreeTibet', 73),
#  ('cowin', 73),
#  ('today', 72),
#  ('modi', 72),
#  ('emergency', 72),
#  ('Lebanon', 71),
#  ('LKA', 71),
#  ('help', 71),
#  ('DRreddys', 71),
#  ('COVISHEILD', 71),
#  ('Covid19IndiaHelp', 71),
#  ('America', 70),
#  ('who', 70),
#  ('mrna', 70),
#  ('novavax', 70),
#  ('Srilanka', 70),
#  ('Cowin', 70),
#  ('NCOC', 70),
#  ('covidindia', 70),
#  ('clinicaltrials', 69),
#  ('BoycottSinovac', 69),
#  ('BoycottSinopharm', 69),
#  ('VaccinationForAll', 69),
#  ('OxygenConcentrator', 69),
#  ('UnitedStates', 68),
#  ('travel', 68),
#  ('igottheshot', 68),
#  ('Norway', 68),
#  ('HoldChinaAccountable', 68),
#  ('farmlaws', 68),
#  ('powell', 68),
#  ('vaccinerollout', 67),
#  ('JohnsonJohnson', 67),
#  ('NHSCovidVaccine', 67),
#  ('Healthcare', 66),
#  ('HerdImmunity', 66),
#  ('cdc', 66),
#  ('DrReddys', 66),
#  ('StayHomeStaySafe', 66),
#  ('pharma', 65),
#  ('uk', 65),
#  ('Biology', 65),
#  ('FAIL', 65),
#  ('oxygenPlants', 65),
#  ('England', 64),
#  ('SerumInstitute', 64),
#  ('variant', 64),
#  ('IndiaPostUSA', 64),
#  ('AstraZeneka', 64),
#  ('Appointments', 64),
#  ('TikaUtsav', 64),
#  ('UN', 63),
#  ('RahulGandhi', 63),
#  ('EUL', 63),
#  ('ThirdWave', 63),
#  ('Easter', 63),
#  ('tuesdayvibe', 62),
#  ('wednesdaythought', 62),
#  ('JNJ', 62),
#  ('daytrading', 62),
#  ('remdesivir', 62),
#  ('Preclinical', 62),
#  ('covidshield', 61),
#  ('HIV', 61),
#  ('vaccineforall', 61),
#  ('Bangalore', 61),
#  ('J', 60),
#  ('premiaholdings', 60),
#  ('UttarPradesh', 60),
#  ('DrugDiscovery', 60),
#  ('GST', 60),
#  ('Facebook_Marketing', 60),
#  ('Digital_Marketing', 60),
#  ('Facebook_ads', 60),
#  ('Ads_Campaign', 60),
#  ('NYC', 59),
#  ('Vaccin', 59),
#  ('bcpoli', 59),
#  ('economy', 59),
#  ('SputnikVaccinated', 59),
#  ('Biotech', 59),
#  ('CoWin', 59),
#  ('AnthonyFauci', 58),
#  ('Covid19India', 58),
#  ('Coronavac', 58),
#  ('Austria', 58),
#  ('disease', 58),
#  ('fullyvaccinated', 58),
#  ('VaccinateEveryIndian', 58),
#  ('oxygencylinder', 58),
#  ('FirstDose', 57),
#  ('World', 57),
#  ('janssen', 57),
#  ('Nifty', 57),
#  ('PMOIndia', 57),
#  ('Navalny', 57),
#  ('yields', 57),
#  ('DrugDesign', 57),
#  ('biontech', 56),
#  ('Grateful', 56),
#  ('Japan', 56),
#  ('HBDMKStalin', 56),
#  ('AtmanirbharBharat', 56),
#  ('Chemistry', 56),
#  ('delhi', 56),
#  ('icu', 56),
#  ('Ramadan2021', 56),
#  ('StockMarketNews', 56),
#  ('myocarditis', 56),
#  ('VirtualEvent', 56),
#  ('urgent', 56),
#  ('CowinPortal', 56),
#  ('CCPVirus', 55),
#  ('Gaza', 55),
#  ('lockdowns', 55),
#  ('VIRTUALPDDP', 55),
#  ('icubed', 55),
#  ('DNA', 54),
#  ('PfizerCOVIDvaccine', 54),
#  ('Bitcoin', 54),
#  ('Kerala', 54),
#  ('à¹\x82à¸\x84à¸§à¸´à¸\x9419', 54),
#  ('BreakTheChain', 54),
#  ('GetVaccinatedASAP', 54),
#  ('Vaccinate', 53),
#  ('VaccineStrategy', 53),
#  ('dollyparton', 53),
#  ('premiameds', 53),
#  ('Venezuela', 53),
#  ('Duterte', 53),
#  ('Ahmedabad', 53),
#  ('IndianVariant', 53),
#  ('OperationWarpSpeed', 52),
#  ('UPDATE', 52),
#  ('StopTheSpread', 52),
#  ('johnson', 52),
#  ('CoronaVaccineUpdates', 52),
#  ('DrHarshVardhan', 52),
#  ('Covidshield', 52),
#  ('SastaBhiKargarBhi', 52),
#  ('maskupindia', 52),
#  ('bed', 52),
#  ('vaccinebot', 52),
#  ('Trending', 51),
#  ('SocialDistancing', 51),
#  ('eu', 51),
#  ('Ireland', 51),
#  ('CoviShield', 51),
#  ('efficacy', 51),
#  ('TakeYourShot', 51),
#  ('CoronaPatients', 51),
#  ('fauciouchie', 51),
#  ('finance', 51),
#  ('Coimbatore', 51),
#  ('Kenya', 51),
#  ('Britain', 50),
#  ('NIH', 50),
#  ('CoronaVaccineNews', 50),
#  ('love', 50),
#  ('Astrazenaca', 50),
#  ('pmmodi', 50),
#  ('helpnagar', 50),
#  ('Covifor', 50),
#  ('pfizervaccine', 49),
#  ('Algeria', 49),
#  ('Morocco', 49),
#  ('Bharat', 49),
#  ('Islamabad', 49),
#  ('SputnikLight', 49),
#  ('malaysia', 49),
#  ('IBM', 49),
#  ('SputnikVaccineInKenya', 49),
#  ('ventilator', 49),
#  ('SideEffects', 48),
#  ('canada', 48),
#  ('DrFauci', 48),
#  ('Vaccinatie', 48),
#  ('BorisJohnson', 48),
#  ('Taiwan', 48),
#  ('vaxxed', 48),
#  ('Pharma', 48),
#  ('Vietnam', 48),
#  ('nonprofit', 48),
#  ('Stimuluschecks', 48),
#  ('DRREDDY', 48),
#  ('CoronaCurfew', 48),
#  ('FreeVaccineForAll', 48),
#  ('Merkel', 47),
#  ('CovidVaccinesideeffects', 47),
#  ('Indians', 47),
#  ('ChinaLiedPeopleDied', 47),
#  ('budget', 47),
#  ('Chhattisgarh', 47),
#  ('CoVaxin', 47),
#  ('SputnikVaccine', 47),
#  ('BangaloreUrban', 47),
#  ('Brexit', 46),
#  ('doses', 46),
#  ('Qatar', 46),
#  ('secondshot', 46),
#  ('politics', 46),
#  ('Peru', 46),
#  ('CovaxiUpdates', 46),
#  ('technicalanalysis', 46),
#  ('Beijing', 46),
#  ('Seychelles', 46),
#  ('firstdosedone', 46),
#  ('airtel', 46),
#  ('FightAgainstCOVID19', 46),
#  ('CoronaUpdate', 46),
#  ('CovidHelp', 46),
#  ('FMTNews', 45),
#  ('thankyouscience', 45),
#  ('Tesla', 45),
#  ('Wales', 45),
#  ('Vaccinations', 45),
#  ('Lancet', 45),
#  ('Belarus', 45),
#  ('banknifty', 45),
#  ('congressmuktbharat', 45),
#  ('usa', 44),
#  ('business', 44),
#  ('Wuhan', 44),
#  ('shot', 44),
#  ('Palestine', 44),
#  ('Odisha', 44),
#  ('PMCaresFund', 44),
#  ('getvaccienated', 44),
#  ('nifty50', 44),
#  ('covid19india', 44),
#  ('koolex', 44),
#  ('covax', 43),
#  ('AbuDhabi', 43),
#  ('ChinaVirus', 43),
#  ('SouthKorea', 43),
#  ('thankful', 43),
#  ('5G', 43),
#  ('antibodies', 43),
#  ('FreeHK', 43),
#  ('NATO', 43),
#  ('SII', 43),
#  ('DelhiHighCourt', 43),
#  ('Pzifer', 43),
#  ('B1617', 43),
#  ('vaccinationfor18plus', 43),
#  ('USFDA', 43),
#  ('scientists', 42),
#  ('InformedConsent', 42),
#  ('Spain', 42),
#  ('CovidVaccineIndia', 42),
#  ('Karachi', 42),
#  ('Iraq', 42),
#  ('Congo', 42),
#  ('wipro', 42),
#  ('fullyvacinnated', 42),
#  ('MaharashtraNeedsVaccine', 42),
#  ('IndiaCovidCrisis', 42),
#  ('Virus', 41),
#  ('GSK', 41),
#  ('Phizer', 41),
#  ('AMC', 41),
#  ('Children', 41),
#  ('Bolivia', 41),
#  ('MRNA', 41),
#  ('Coronil', 41),
#  ('RESBAKUNA', 41),
#  ('DailyVoice', 41),
#  ('NSE', 41),
#  ('MajorTeaser', 41),
#  ('DelhiFightsCorona', 41),
#  ('Vivek', 41),
#  ('Social_Media_Marketing', 41),
#  ('safety', 40),
#  ('Amazon', 40),
#  ('Tunisia', 40),
#  ('Texas', 40),
#  ('cryptocurrency', 40),
#  ('EpiVacCorona', 40),
#  ('Pakistani', 40),
#  ('slovakia', 40),
#  ('We4Vaccine', 40),
#  ('ISIS', 40),
#  ('Guwahati', 40),
#  ('Gurgaon', 40),
#  ('PanaceaBiotec', 40),
#  ('WuhanVirus', 39),
#  ('CNN', 39),
#  ('pfizervacine', 39),
#  ('IndiaNarrative', 39),
#  ('coronavirusuk', 39),
#  ('immunity', 39),
#  ('COVIDvaccines', 39),
#  ('covid19vaccines', 39),
#  ('herdimmunity', 39),
#  ('CoronaCasesIndia', 39),
#  ('ThailandNews', 39),
#  ('Rajasthan', 39),
#  ('n95', 39),
#  ('ICYMI', 38),
#  ('PFIZERBIONTECH', 38),
#  ('frontlineworkers', 38),
#  ('development', 38),
#  ('Denmark', 38),
#  ('massacre', 38),
#  ('CureVac', 38),
#  ('B1351', 38),
#  ('vax', 38),
#  ('icmr', 38),
#  ('MEDIA', 38),
#  ('Book', 38),
#  ('PMNarendraModi', 38),
#  ('coronavirusindia', 38),
#  ('FastForNation', 38),
#  ('Kolkata', 38),
#  ('ChineseVaccine', 38),
#  ('BSE', 38),
#  ('technology', 37),
#  ('God', 37),
#  ('vaccin', 37),
#  ('Florida', 37),
#  ('blessed', 37),
#  ('socialdistancing', 37),
#  ('covidvaccines', 37),
#  ('BioNTechpfizer', 37),
#  ('TikTok', 37),
#  ('Gamaleya', 37),
#  ('SmartNews', 37),
#  ('Bhubaneswar', 37),
#  ('chinesevaccine', 37),
#  ('Clairvoyant', 37),
#  ('PSYCHIC', 37),
#  ('Armenia', 37),
#  ('MKStalin', 37),
#  ('CGBudget2021', 37),
#  ('firstshot', 37),
#  ('OxygenShortage', 37),
#  ('COVIDEmergencyIndia', 37),
#  ('covidhelpline', 37),
#  ('EURO2020', 37),
#  ('Impfung', 36),
#  ('thankyouNHS', 36),
#  ('Covid19Vaccines', 36),
#  ('Delta', 36),
#  ('putin', 36),
#  ('Senegal', 36),
#  ('HealthMinistry', 36),
#  ('GetTheShot', 36),
#  ('IndianArmy', 36),
#  ('UnlockOurCountry', 36),
#  ('Protein', 36),
#  ('ThaneCOVAXIN', 36),
#  ('stayhome', 35),
#  ('PfizerProud', 35),
#  ('thankyou', 35),
#  ('coronaviruspandemic', 35),
#  ('FarmersProstests', 35),
#  ('family', 35),
#  ('premiamedical', 35),
#  ('VaccineEquity', 35),
#  ('JaiHind', 35),
#  ('Crypto', 35),
#  ('telecom', 35),
#  ('jio', 35),
#  ('Mauritius', 35),
#  ('banking', 35),
#  ('É¢á´\x87á´\x9bá´\xa0á´\x80á´\x84á´\x84ÉªÉ´á´\x80á´\x9bá´\x87á´\x85', 35),
#  ('covaxinated', 35),
#  ('ApolloHospital', 35),
#  ('MSNBC', 34),
#  ('healthcareworkers', 34),
#  ('IGotTheShot', 34),
#  ('vaccineswork', 34),
#  ('vaccinessavelives', 34),
#  ('trustscience', 34),
#  ('SARS_CoV_2', 34),
#  ('art', 34),
#  ('London', 34),
#  ('podcast', 34),
#  ('comirnaty', 34),
#  ('Covid19Lockdown', 34),
#  ('Azerbaijan', 34),
#  ('fridaymorning', 34),
#  ('teammoderna', 34),
#  ('CHINA', 34),
#  ('Everlane', 34),
#  ('SupremeCourt', 34),
#  ('Airdrop', 34),
#  ('resbakuna', 34),
#  ('bseindia', 34),
#  ('Vaccinateindia', 34),
#  ('NSTworld', 33),
#  ('Video', 33),
#  ('world', 33),
#  ('COVID19PH', 33),
#  ('effective', 33),
#  ('hospitals', 33),
#  ('CVS', 33),
#  ('Facebook', 33),
#  ('SINOPHARM', 33),
#  ('AmitShah', 33),
#  ('Bihar', 33),
#  ('Haryana', 33),
#  ('srilanka', 33),
#  ('thesundaily', 33),
#  ('summer', 33),
#  ('AssamCovidUpdate', 33),
#  ('Mangalore', 33),
#  ('MHRA', 32),
#  ('CoronaVirusUpdate', 32),
#  ('CyberSecurity', 32),
#  ('Immunity', 32),
#  ('NurembergCode', 32),
#  ('quarantine', 32),
#  ('ASTRAZENECA', 32),
#  ('Libya', 32),
#  ('Uruguay', 32),
#  ('covid19malaysia', 32),
#  ('P1', 32),
#  ('covaxinvaccine', 32),
#  ('JnJ', 32),
#  ('investments', 32),
#  ('Vaxzevria', 32),
#  ('MaskUpIndia', 32),
#  ('covid1948', 32),
#  ('NHSheroes', 31),
#  ('Business', 31),
#  ('GreatReset', 31),
#  ('COVID19ireland', 31),
#  ('WorldHealthOrganization', 31),
#  ('dose', 31),
#  ('StaySafeStayHealthy', 31),
#  ('pharmacy', 31),
#  ('freedom', 31),
#  ('amazon', 31),
#  ('Scientist', 31),
#  ('COVIDVACCINE', 31),
#  ('getyourshot', 31),
#  ('Ethereum', 31),
#  ('à¤¬à¤¿à¤¹à¤¾à¤°_à¤¬à¥\x87à¤°à¥\x8bà¤\x9cà¤\x97à¤¾à¤°à¥\x80_à¤¦à¤¿à¤µà¤¸',
#   31),
#  ('European', 31),
#  ('Cameroon', 31),
#  ('Growth', 31),
#  ('ApolloHospitals', 31),
#  ('fda', 30),
#  ('safe', 30),
#  ('Thankful', 30),
#  ('Macron', 30),
#  ('AstraZenecaVaccine', 30),
#  ('nurses', 30),
#  ('FreeSpeech', 30),
#  ('Switzerland', 30),
#  ('government', 30),
#  ('Antibodies', 30),
#  ('data', 30),
#  ('NewsAlert', 30),
#  ('worldnews', 30),
#  ('Twitter', 30),
#  ('Afghanistan', 30),
#  ('globalhealth', 30),
#  ('kids', 30),
#  ('snow', 30),
#  ('GregPalast', 30),
#  ('Jaipur', 30),
#  ('Colombo', 30),
#  ('MotivationMonday', 30),
#  ('thesun', 30),
#  ('Apollo', 30),
#  ('BTSARMY', 30),
#  ('VaccinationUpdate', 30),
#  ('AntibodySequencing', 30),
#  ('ModiSpeech', 30),
#  ('HealthcareHeroes', 29),
#  ('SaveLives', 29),
#  ('life', 29),
#  ('covid19news', 29),
#  ('1stDose', 29),
#  ('RedFort', 29),
#  ('growth', 29),
#  ('VladimirPutin', 29),
#  ('Pharmaceutical', 29),
#  ('VaccinateNY', 29),
#  ('1stdose', 29),
#  ('Lahore', 29),
#  ('CCPCHINA', 29),
#  ('thursdaymorning', 29),
#  ('Censorship', 29),
#  ('JammuAndKashmir', 29),
#  ('covisheild', 29),
#  ('FarmLaws', 29),
#  ('cancelboardexams2021', 29),
#  ('cancelboardexam2021', 29),
#  ('Haffkine', 29),
#  ('Nashik', 29),
#  ('NEET', 29),
#  ('YellowCard', 29),
#  ('MyBMCVaccinationUpdate', 29),
#  ('Jammu', 29),
#  ('ThankYouNHS', 28),
#  ('vaccino', 28),
#  ('VaccinesForAll', 28),
#  ('doingmypart', 28),
#  ('Asia', 28),
#  ('uae', 28),
#  ('vaccinationCovid', 28),
#  ('Bosnia', 28),
#  ('Greece', 28),
#  ('doctors', 28),
#  ('NewsUpdate', 28),
#  ('novovax', 28),
#  ('seruminstituteofindia', 28),
#  ('à¸§à¸±à¸\x84à¸\x8bà¸µà¸\x99à¹\x82à¸\x84à¸§à¸´à¸\x9419', 28),
#  ('doyourpart', 28),
#  ('covid19vaccination', 28),
#  ('COMMUNISTCHINA', 28),
#  ('Somalia', 28),
#  ('IPL2021', 28),
#  ('Motivation', 28),
#  ('ymedia', 28),
#  ('mco2021', 28),
#  ('CAA', 28),
#  ('IndianLivesMatter', 28),
#  ('justice', 28),
#  ('SecondDoses', 28),
#  ('Clinical', 28),
#  ('tourism', 27),
#  ('LosAngeles', 27),
#  ('Cyprus', 27),
#  ('Research', 27),
#  ('PrimeMinister', 27),
#  ('production', 27),
#  ('wellness', 27),
#  ('cryptocurrencies', 27),
#  ('Sindh', 27),
#  ('SLnews', 27),
#  ('chinavirus', 27),
#  ('media', 27),
#  ('ModeRNA', 27),
#  ('ZimVaccination', 27),
#  ('VaccineScandal', 27),
#  ('Paraguay', 27),
#  ('design', 27),
#  ('PetrolPrices', 27),
#  ('JJ', 27),
#  ('shots', 27),
#  ('pune', 27),
#  ('SpeakUpForVaccinesForAll', 27),
#  ('Chess', 27),
#  ('bbcnews', 26),
#  ('NewYork', 26),
#  ('nurse', 26),
#  ('Medical', 26),
#  ('Government', 26),
#  ('ivermectin', 26),
#  ('fakenews', 26),
#  ('booster', 26),
#  ('UnitedKingdom', 26),
#  ('immunization', 26),
#  ('dogecoin', 26),
#  ('worthit', 26),
#  ('aztrazeneca', 26),
#  ('HarshVardhan', 26),
#  ('pakistan', 26),
#  ('aiims', 26),
#  ('SafeVaccines', 26),
#  ('largestvaccinationdrive', 26),
#  ('PM', 26),
#  ('ITVideo', 26),
#  ('TV9News', 26),
#  ('Albania', 26),
#  ('Fortis', 26),
#  ('SecondWave', 26),
#  ('ModernaGang', 26),
#  ('UhuruMalizaUende', 26),
#  ('fullyvaxxed', 26),
#  ('trump', 25),
#  ('singapore', 25),
#  ('vaccinehesitancy', 25),
#  ('BC', 25),
#  ('pregnant', 25),
#  ('LongCovid', 25),
#  ('PfizerBionTech', 25),
#  ('Variant', 25),
#  ('Cancer', 25),
#  ('biden', 25),
#  ('clinicaltrial', 25),
#  ('Sweden', 25),
#  ('HumanRights', 25),
#  ('Covid19vaccines', 25),
#  ('covidvac', 25),
#  ('dose2', 25),
#  ('COVIDisAirborne', 25),
#  ('HK', 25),
#  ('pandemiclife', 25),
#  ('bharatbiotechnews', 25),
#  ('RussianVaccine', 25),
#  ('Czech', 25),
#  ('Investment', 25),
#  ('volunteers', 25),
#  ('propaganda', 25),
#  ('Who', 25),
#  ('StocksInNews', 25),
#  ('disinformation', 25),
#  ('stockmarketnews', 25),
#  ('ModiHaiToMumkinHai', 25),
#  ('Coronavaccine', 25),
#  ('WestBengal', 25),
#  ('COVIDVaccineArrives', 25),
#  ('StocksInFocus', 25),
#  ('TeamModerna', 25),
#  ('TexansRecoveringTogether', 25),
#  ('Indiafightscorona', 25),
#  ('GetVaxxed', 25),
#  ('Dynamite1B', 25),
#  ('Oxygen', 25),
#  ('1stdosecovid19vaccine', 25),
#  ('vaccinatedandhappy', 25),
#  ...]

# %%
pfizer_biontech_vax = ["Pfizer", "PFIZER", "PfizerBioNTech", "PfizerVaccine", "pfizer", "PfizerBiontech", "BioNTech", "pfizerbiontech", "PfizerBioNtech", "Biontech", "biontech", "PFIZERBIONTECH", "BioNTechpfizer"]
sputnik_vax = ["SputnikV", "Sputnik", "Sputnikv", "sputnikv", "SputnikUpdates", "Sputnikvaccine", "sputnikV", "sputnik", "SPUTNIKV", "SputnikVaccinated", "SputnikLight", "SputnikVaccineInKenya", "SputnikVaccine"]
sinopharm_vax = ["Sinopharm", "sinopharm", "SinoPharm", "BoycottSinopharm", "SINOPHARM"]
sinovac_vax = ["Sinovac", "sinovac", "SinoVac", "SINOVAC", "BoycottSinovac"]
moderna_vax = ["Moderna", "moderna", "modernavaccine", "MODERNA", "ModernaVaccine", "modernagang", "teammoderna", "modeRNA", "ModernaGang"]
oxford_az_vax = ["OxfordAstraZeneca", "oxfordastrazeneca", "Oxford", "oxfordvaccine", "OxfordVaccine", "OxfordAstrazeneca", "AstraZeneca", "astrazeneca", "AstraZenaca", "astrazenecavaccine", "Astrazeneca", "AstraZeneka", "Astrazenaca", "ASTRAZENECA", "AstraZenecaVaccine"]
covaxin_vax = ["Covaxin", "COVAXIN", "covaxin", "GurgaonCOVAXIN", "MumbaiCOVAXIN", "covaxine", "BBMPCOVAXIN", "PuneCOVAXIN", "CoVaxin", "ThaneCOVAXIN", "covaxinated", "covaxinvaccine", "BharatBiotech", "AatmanirbharBharat", "AtmaNirbharBharat", "bharatbiotech", "bharatBiotech", "AtmanirbharBharat", "Bharat", "congressmuktbharat", "atmanirbharbharat"]
jandj_vax = ["johnsonandjohnson", "JohnsonandJohnson", "JohnsonAndJohnson", "JohnsonAndJohnsonVaccine", "Johnson", "JandJ", "JohnsonJohnson", "johnson", "JJ"]

# %% [markdown]
# normalizing hashtags to all lowercase:

# %%
for i in range(0, len(raw_vaccine_tweets)):
    for j in range(len(raw_vaccine_tweets["hashtags"][i])):
        review = raw_vaccine_tweets["hashtags"][i][j]
        review = review.lower()
        raw_vaccine_tweets["hashtags"][i][j] = review

# %% [markdown]
# adding columns for each vaccine manufacturer, based on the hashtags of a tweet:

# %%
raw_vaccine_tweets["PfizerBiontech"] = 0
raw_vaccine_tweets["SputnikV"] = 0
raw_vaccine_tweets["Sinopharm"] = 0
raw_vaccine_tweets["Sinovac"] = 0
raw_vaccine_tweets["Moderna"] = 0
raw_vaccine_tweets["AstraZeneca"] = 0
raw_vaccine_tweets["Covaxin"] = 0
raw_vaccine_tweets["JandJ"] = 0

# %%
for i in range(len(raw_vaccine_tweets)):
    for hashtag in raw_vaccine_tweets["hashtags"][i]:
        if hashtag in pfizer_biontech_vax:
            raw_vaccine_tweets["PfizerBiontech"][i] = 1
        if hashtag in sputnik_vax:
            raw_vaccine_tweets["SputnikV"][i] = 1
        if hashtag in sinopharm_vax:
            raw_vaccine_tweets["Sinopharm"][i] = 1
        if hashtag in sinovac_vax:
            raw_vaccine_tweets["Sinovac"][i] = 1
        if hashtag in moderna_vax:
            raw_vaccine_tweets["Moderna"][i] = 1
        if hashtag in oxford_az_vax:
            raw_vaccine_tweets["AstraZeneca"][i] = 1
        if hashtag in covaxin_vax:
            raw_vaccine_tweets["Covaxin"][i] = 1
        if hashtag in jandj_vax:
            raw_vaccine_tweets["JandJ"][i] = 1
# Out:
# <ipython-input-19-0e6b7adc50b2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["PfizerBiontech"][i] = 1
# <ipython-input-19-0e6b7adc50b2>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["Moderna"][i] = 1
# <ipython-input-19-0e6b7adc50b2>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["AstraZeneca"][i] = 1
# <ipython-input-19-0e6b7adc50b2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["Sinopharm"][i] = 1
# <ipython-input-19-0e6b7adc50b2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["Covaxin"][i] = 1
# <ipython-input-19-0e6b7adc50b2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["SputnikV"][i] = 1
# <ipython-input-19-0e6b7adc50b2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["Sinovac"][i] = 1
# <ipython-input-19-0e6b7adc50b2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["JandJ"][i] = 1

# %% [markdown]
# ---

# %%
from geopy import Nominatim
import reverse_geocode

# %% [markdown]
# ## Geo location

# %% [markdown]
# - Filtering out all tweets that had a geolocation when tweeted
# - storing geo location as coordinates and as countryname

# %% [markdown]
# - [x] country from user location
# - [x] transform the country to coordinates (whole df) (store in "coordinates")
# - [x] overwrite coordinates that are in geo originally, and in same loop add country name to "country"
# - [ ] that way we have all coordinates and all country names

# %% [markdown]
# adding geolocation from user location:

# %% [markdown]
# - get geolocation from user info, for that:
#     - check if one of the countries in countries list is in the user_location, if so, assign that country to him
#     - in second  step, use that country in geopy to get lat&long
# - apply geopy to turn geolocation to coordinates
# - if geo is empty then fill it with other value otherwise leave it as is

# %% [markdown]
# Fetching location specified in user profile:

# %%
raw_vaccine_tweets["user_location"] = None
for i in range(len(raw_vaccine_tweets["user"])):
    raw_vaccine_tweets["user_location"][i] = raw_vaccine_tweets["user"][i]["location"]
# Out:
# <ipython-input-21-bf0c79a898dc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["user_location"][i] = raw_vaccine_tweets["user"][i]["location"]

# %%
countries = ['argentina', 'australia', 'austria', 'belgium', 'brazil', 'canada', 'france', 'germany', 'india', 'israel', 'italy', 'japan', 'mexico', 'pakistan', 'russia', 'spain', 'uae', 'uk', 'usa']

# %% [markdown]
# set the country in user profile to the normalized country name:

# %%
#set country for locations that contain that country
for country in countries :
    raw_vaccine_tweets["user_location"][raw_vaccine_tweets["user_location"].str.lower().str.contains(country)] = country

#remove any location that isn't in country-list
for i in range(len(raw_vaccine_tweets)):
    if raw_vaccine_tweets["user_location"][i] not in countries:
        raw_vaccine_tweets["user_location"][i] = None
# Out:
# <ipython-input-23-2f75fae531ee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["user_location"][raw_vaccine_tweets["user_location"].str.lower().str.contains(country)] = country
# <ipython-input-23-2f75fae531ee>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["user_location"][i] = None

# %% [markdown]
# create new dataframe with locations only:

# %% [markdown]
# get coordinates for every country:

# %%
geolocator = Nominatim(user_agent="CovaxAnalytica")
location_coordinates = {}

for country in countries:
    location = geolocator.geocode(country)
    try:
        location_coordinates[country] = [location.latitude, location.longitude]
    except:
        location_coordinates[country] = None

# %%
location_coordinates
# Out:
# {'argentina': [-34.9964963, -64.9672817],
#  'australia': [-24.7761086, 134.755],
#  'austria': [47.2, 13.2],
#  'belgium': [50.6402809, 4.6667145],
#  'brazil': [-10.3333333, -53.2],
#  'canada': [61.0666922, -107.991707],
#  'france': [46.603354, 1.8883335],
#  'germany': [51.0834196, 10.4234469],
#  'india': [22.3511148, 78.6677428],
#  'israel': [31.5313113, 34.8667654],
#  'italy': [42.6384261, 12.674297],
#  'japan': [36.5748441, 139.2394179],
#  'mexico': [22.5000485, -100.0000375],
#  'pakistan': [30.3308401, 71.247499],
#  'russia': [64.6863136, 97.7453061],
#  'spain': [39.3260685, -4.8379791],
#  'uae': [49.4871968, 31.2718321],
#  'uk': [54.7023545, -3.2765753],
#  'usa': [39.7837304, -100.4458825]}

# %% [markdown]
# map country name to coordinates:

# %%
raw_vaccine_tweets["coordinates"] = None
for i in range(len(raw_vaccine_tweets)):
     if raw_vaccine_tweets["user_location"][i] in countries:
        raw_vaccine_tweets["coordinates"][i] = location_coordinates[raw_vaccine_tweets["user_location"][i].lower()]
# Out:
# <ipython-input-26-54fe49d17fbe>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets["coordinates"][i] = location_coordinates[raw_vaccine_tweets["user_location"][i].lower()]

# %%
raw_vaccine_tweets
# Out:
#                          id                created_at  \
# 0       1338158543359250432 2020-12-13 16:27:13+00:00
# 1       1337840331522453504 2020-12-12 19:22:45+00:00
# 2       1338544403795881984 2020-12-14 18:00:29+00:00
# 3       1337735595704115200 2020-12-12 12:26:34+00:00
# 4       1337850832256176128 2020-12-12 20:04:29+00:00
# ...                     ...                       ...
# 101018  1403362726521438208 2021-06-11 14:45:21+00:00
# 101019  1403638668418420736 2021-06-12 09:01:51+00:00
# 101020  1403728228548628480 2021-06-12 14:57:44+00:00
# 101021  1403606811299631104 2021-06-12 06:55:16+00:00
# 101022  1403390113778868224 2021-06-11 16:34:11+00:00
#
#                                                      user   geo  \
# 0       {'id': 76052772, 'id_str': '76052772', 'name':...  None
# 1       {'id': 1300382181605494800, 'id_str': '1300382...  None
# 2       {'id': 1164717209253552000, 'id_str': '1164717...  None
# 3       {'id': 1316036067754205200, 'id_str': '1316036...  None
# 4       {'id': 1110032180237852700, 'id_str': '1110032...  None
# ...                                                   ...   ...
# 101018  {'id': 1504133713, 'id_str': '1504133713', 'na...  None
# 101019  {'id': 3029283761, 'id_str': '3029283761', 'na...  None
# 101020  {'id': 1072356934148251600, 'id_str': '1072356...  None
# 101021  {'id': 1204276725372215300, 'id_str': '1204276...  None
# 101022  {'id': 1050804894133874700, 'id_str': '1050804...  None
#
#                                                 full_text  \
# 0       While the world has been on the wrong side of ...
# 1       @cnnbrk #COVID19 #CovidVaccine #vaccine #Coron...
# 2       The FDA Authorizes Emergency Use Of The Pfizer...
# 3       The #FDA finally issues #EUA now comes the pro...
# 4       There have not been many bright days in 2020 b...
# ...                                                   ...
# 101018  Those making issue of #covaxine should know th...
# 101019  How much more time will #Sputnik take to be av...
# 101020  Intl renown broadcaster @mattfrei discussed Va...
# 101021  #Getvaccinated, Be informed!\n\n#breakthechain...
# 101022  COVID-19 vaccination proceeds slowly in Abkhaz...
#
#                                                  hashtags  \
# 0       [covid19, supplychain, logistics, vaccine, uni...
# 1       [covid19, covidvaccine, vaccine, corona, pfize...
# 2       [pfe, pfizer, pfizervaccine, pfizerbiontech, f...
# 3                  [fda, eua, pfizerbiontech, vaccinated]
# 4       [bidenharris, election2020, pfizerbiontech, co...
# ...                                                   ...
# 101018                               [covaxine, sputnikv]
# 101019                                [sputnik, sputnikv]
# 101020                [sinopharm, sinovac, sputnikv, sad]
# 101021  [getvaccinated, breakthechain, getyourfactsrig...
# 101022  [sputnikv, sputnikvaccine, sputnikvidaargentin...
#
#                     user_id  PfizerBiontech  SputnikV  Sinopharm  Sinovac  \
# 0                  76052772               1         0          0        0
# 1       1300382181605494800               1         0          0        0
# 2       1164717209253552000               1         0          0        0
# 3       1316036067754205200               1         0          0        0
# 4       1110032180237852700               1         0          0        0
# ...                     ...             ...       ...        ...      ...
# 101018           1504133713               0         1          0        0
# 101019           3029283761               0         1          0        0
# 101020  1072356934148251600               0         1          1        1
# 101021  1204276725372215300               0         1          0        0
# 101022  1050804894133874700               0         1          0        0
#
#         Moderna  AstraZeneca  Covaxin  JandJ user_location  \
# 0             0            0        0      0          None
# 1             0            0        0      0          None
# 2             0            0        0      0          None
# 3             0            0        0      0          None
# 4             0            0        0      0          None
# ...         ...          ...      ...    ...           ...
# 101018        0            0        1      0         india
# 101019        0            0        0      0          None
# 101020        0            0        0      0          None
# 101021        0            0        1      0          None
# 101022        0            0        0      0          None
#
#                      coordinates
# 0                           None
# 1                           None
# 2                           None
# 3                           None
# 4                           None
# ...                          ...
# 101018  [22.3511148, 78.6677428]
# 101019                      None
# 101020                      None
# 101021                      None
# 101022                      None
#
# [101023 rows x 17 columns]

# %% [markdown]
# add coordinates from geo:

# %%
for i in range(len(raw_vaccine_tweets)):
    if raw_vaccine_tweets.geo[i] != None:
        raw_vaccine_tweets.coordinates[i] = raw_vaccine_tweets.geo[i]["coordinates"]
# Out:
# <ipython-input-28-35795c746503>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets.coordinates[i] = raw_vaccine_tweets.geo[i]["coordinates"]

# %% [markdown]
# renaming all countries in standardized way

# %%
for i in range(len(raw_vaccine_tweets)):
    if raw_vaccine_tweets.coordinates[i] != None:
        raw_vaccine_tweets.user_location[i] = reverse_geocode.search(tuple([raw_vaccine_tweets.coordinates[i],(1,1)]))[0]["country"]
# Out:
# <ipython-input-29-d848799ac007>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_vaccine_tweets.user_location[i] = reverse_geocode.search(tuple([raw_vaccine_tweets.coordinates[i],(1,1)]))[0]["country"]

# %%
raw_vaccine_tweets["user_location"].unique()
# Out:
# array([None, 'Canada', 'Palestinian Territory', 'India', 'Germany',
#        'United States', 'Italy', 'United Kingdom', 'France',
#        'Russian Federation', 'Mexico', 'Belgium', 'Spain', 'Australia',
#        'Pakistan', 'Ukraine', 'Argentina', 'Austria',
#        'Virgin Islands, U.S.', 'Malaysia', 'Japan', 'Brazil',
#        'United Arab Emirates', 'Jersey', 'Philippines', 'Chile',
#        'Indonesia', 'Hong Kong', 'Qatar', 'Netherlands', 'China',
#        'Saudi Arabia', 'Guyana', 'Thailand', 'Singapore', 'Croatia',
#        'Switzerland', 'Trinidad and Tobago', 'Sweden', 'Greece'],
#       dtype=object)

# %% [markdown]
# # Exporting dataset

# %%
raw_vaccine_tweets.to_csv("../data/interim/cleaned_vaccine_tweets.csv")
